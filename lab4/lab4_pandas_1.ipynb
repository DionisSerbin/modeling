# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from matplotlib import pyplot as plt
import scipy.stats as stats
from sklearn.metrics import mean_squared_error

# %%
pd.set_option('display.max_columns', None, 'display.width', -1)
df = pd.read_csv("place1.csv")
df
# Out:
#        id  \
# 0   kBEdx
# 1   62mP7
# 2   vyE1P
# 3   KcrkZ
# 4   AHL4O
# 5   HHckp
# 6   h5Ujo
# 7   muH9x
# 8   YiRkx
# 9   jG6Gi
# 10  7uHUe
# 11  OXyvW
# 12  cB8re
# 13  igmai
# 14  3OdkE
# 15  3tVUO
# 16  siveY
# 17  gIqzq
# 18  zO5EU
# 19  dkcEb
# 20  X1FZJ
# 21  eVFPS
# 22  TovFu
# 23  KQxAV
# 24  II0xj
# 25  AOrbK
# 26  DbtST
# 27  mqtSN
# 28  dqN1d
# 29  JPiGi
# 30  YVVPX
# 31  4NJv3
# 32  2DKVI
# 33  M57PU
# 34  5O3Zt
# 35  BZWmy
# 36  aArVp
# 37  EHH3V
# 38  fNWXc
# 39  957X9
#
#            f0  \
# 0  -15.001348
# 1   14.272088
# 2    6.263187
# 3  -13.081196
# 4   12.702195
# 5   -3.327590
# 6  -11.142655
# 7    4.234715
# 8   13.355129
# 9    1.069227
# 10  11.777049
# 11  16.320755
# 12   7.736313
# 13   6.695604
# 14 -10.985487
# 15  -0.347599
# 16  12.300570
# 17   8.900460
# 18 -13.412826
# 19  -4.373526
# 20  -5.729511
# 21   2.195392
# 22   9.391662
# 23  10.852199
# 24   2.581392
# 25   2.338888
# 26  -0.524255
# 27   8.921872
# 28  10.373859
# 29 -10.926274
# ...

# %%
df = df.drop(columns=['Unnamed: 5'])
df
# Out:
#        id  \
# 0   kBEdx
# 1   62mP7
# 2   vyE1P
# 3   KcrkZ
# 4   AHL4O
# 5   HHckp
# 6   h5Ujo
# 7   muH9x
# 8   YiRkx
# 9   jG6Gi
# 10  7uHUe
# 11  OXyvW
# 12  cB8re
# 13  igmai
# 14  3OdkE
# 15  3tVUO
# 16  siveY
# 17  gIqzq
# 18  zO5EU
# 19  dkcEb
# 20  X1FZJ
# 21  eVFPS
# 22  TovFu
# 23  KQxAV
# 24  II0xj
# 25  AOrbK
# 26  DbtST
# 27  mqtSN
# 28  dqN1d
# 29  JPiGi
# 30  YVVPX
# 31  4NJv3
# 32  2DKVI
# 33  M57PU
# 34  5O3Zt
# 35  BZWmy
# 36  aArVp
# 37  EHH3V
# 38  fNWXc
# 39  957X9
#
#            f0  \
# 0  -15.001348
# 1   14.272088
# 2    6.263187
# 3  -13.081196
# 4   12.702195
# 5   -3.327590
# 6  -11.142655
# 7    4.234715
# 8   13.355129
# 9    1.069227
# 10  11.777049
# 11  16.320755
# 12   7.736313
# 13   6.695604
# 14 -10.985487
# 15  -0.347599
# 16  12.300570
# 17   8.900460
# 18 -13.412826
# 19  -4.373526
# 20  -5.729511
# 21   2.195392
# 22   9.391662
# 23  10.852199
# 24   2.581392
# 25   2.338888
# 26  -0.524255
# 27   8.921872
# 28  10.373859
# 29 -10.926274
# ...

# %%
df.head()
# Out:
#       id  \
# 0  kBEdx
# 1  62mP7
# 2  vyE1P
# 3  KcrkZ
# 4  AHL4O
#
#           f0  \
# 0 -15.001348
# 1  14.272088
# 2   6.263187
# 3 -13.081196
# 4  12.702195
#
#           f1  \
# 0  -8.276000
# 1  -3.475083
# 2  -5.948386
# 3 -11.506057
# 4  -8.147433
#
#          f2  \
# 0 -0.005876
# 1  0.999183
# 2  5.001160
# 3  4.999415
# 4  5.004363
#
#       product
# 0    3.179103
# 1   26.953261
# 2  134.766305
# 3  137.945408
# 4  134.766305
#       id  \
# 0  kBEdx
# 1  62mP7
# 2  vyE1P
# 3  KcrkZ
# 4  AHL4O
#
#           f0  \
# 0 -15.001348
# 1  14.272088
# 2   6.263187
# 3 -13.081196
# 4  12.702195
#
#           f1  \
# 0  -8.276000
# 1  -3.475083
# 2  -5.948386
# 3 -11.506057
# 4  -8.147433
#
#          f2  \
# 0 -0.005876
# 1  0.999183
# 2  5.001160
# 3  4.999415
# 4  5.004363
#
#       product
# 0    3.179103
# 1   26.953261
# 2  134.766305
# 3  137.945408
# 4  134.766305

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       40 non-null     object
#  1   f0       40 non-null     float64
#  2   f1       40 non-null     float64
#  3   f2       40 non-null     float64
#  4   product  40 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       40 non-null     object
#  1   f0       40 non-null     float64
#  2   f1       40 non-null     float64
#  3   f2       40 non-null     float64
#  4   product  40 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 1.7+ KB

# %%
df.describe()
# Out:
#               f0  \
# count  40.000000
# mean    2.077724
# std     8.823711
# min   -15.001348
# 25%    -4.478392
# 50%     2.460140
# 75%     9.596212
# max    16.320755
#
#               f1  \
# count  40.000000
# mean   -4.821013
# std     4.101341
# min   -13.659814
# 25%    -7.714120
# 50%    -4.793330
# 75%    -2.119299
# max     2.944454
#
#               f2  \
# count  40.000000
# mean    2.899393
# std     1.721036
# min    -0.007630
# 25%     2.002661
# 50%     2.995529
# 75%     4.250260
# max     5.004363
#
#           product
# count   40.000000
# mean    79.675956
# std     46.426570
# min      0.000000
# 25%     53.906522
# 50%     84.038886
# 75%    116.935687
# max    137.945408
#               f0  \
# count  40.000000
# mean    2.077724
# std     8.823711
# min   -15.001348
# 25%    -4.478392
# 50%     2.460140
# 75%     9.596212
# max    16.320755
#
#               f1  \
# count  40.000000
# mean   -4.821013
# std     4.101341
# min   -13.659814
# ...

# %%
df.dropna()
# Out:
#        id  \
# 0   kBEdx
# 1   62mP7
# 2   vyE1P
# 3   KcrkZ
# 4   AHL4O
# 5   HHckp
# 6   h5Ujo
# 7   muH9x
# 8   YiRkx
# 9   jG6Gi
# 10  7uHUe
# 11  OXyvW
# 12  cB8re
# 13  igmai
# 14  3OdkE
# 15  3tVUO
# 16  siveY
# 17  gIqzq
# 18  zO5EU
# 19  dkcEb
# 20  X1FZJ
# 21  eVFPS
# 22  TovFu
# 23  KQxAV
# 24  II0xj
# 25  AOrbK
# 26  DbtST
# 27  mqtSN
# 28  dqN1d
# 29  JPiGi
# 30  YVVPX
# 31  4NJv3
# 32  2DKVI
# 33  M57PU
# 34  5O3Zt
# 35  BZWmy
# 36  aArVp
# 37  EHH3V
# 38  fNWXc
# 39  957X9
#
#            f0  \
# 0  -15.001348
# 1   14.272088
# 2    6.263187
# 3  -13.081196
# 4   12.702195
# 5   -3.327590
# 6  -11.142655
# 7    4.234715
# 8   13.355129
# 9    1.069227
# 10  11.777049
# 11  16.320755
# 12   7.736313
# 13   6.695604
# 14 -10.985487
# 15  -0.347599
# 16  12.300570
# 17   8.900460
# 18 -13.412826
# 19  -4.373526
# 20  -5.729511
# 21   2.195392
# 22   9.391662
# 23  10.852199
# 24   2.581392
# 25   2.338888
# 26  -0.524255
# 27   8.921872
# 28  10.373859
# 29 -10.926274
# ...

# %%
df.drop_duplicates()
# Out:
#        id  \
# 0   kBEdx
# 1   62mP7
# 2   vyE1P
# 3   KcrkZ
# 4   AHL4O
# 5   HHckp
# 6   h5Ujo
# 7   muH9x
# 8   YiRkx
# 9   jG6Gi
# 10  7uHUe
# 11  OXyvW
# 12  cB8re
# 13  igmai
# 14  3OdkE
# 15  3tVUO
# 16  siveY
# 17  gIqzq
# 18  zO5EU
# 19  dkcEb
# 20  X1FZJ
# 21  eVFPS
# 22  TovFu
# 23  KQxAV
# 24  II0xj
# 25  AOrbK
# 26  DbtST
# 27  mqtSN
# 28  dqN1d
# 29  JPiGi
# 30  YVVPX
# 31  4NJv3
# 32  2DKVI
# 33  M57PU
# 34  5O3Zt
# 35  BZWmy
# 36  aArVp
# 37  EHH3V
# 38  fNWXc
# 39  957X9
#
#            f0  \
# 0  -15.001348
# 1   14.272088
# 2    6.263187
# 3  -13.081196
# 4   12.702195
# 5   -3.327590
# 6  -11.142655
# 7    4.234715
# 8   13.355129
# 9    1.069227
# 10  11.777049
# 11  16.320755
# 12   7.736313
# 13   6.695604
# 14 -10.985487
# 15  -0.347599
# 16  12.300570
# 17   8.900460
# 18 -13.412826
# 19  -4.373526
# 20  -5.729511
# 21   2.195392
# 22   9.391662
# 23  10.852199
# 24   2.581392
# 25   2.338888
# 26  -0.524255
# 27   8.921872
# 28  10.373859
# 29 -10.926274
# ...

# %%
df.isnull()
# Out:
#        id  \
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False
# 10  False
# 11  False
# 12  False
# 13  False
# 14  False
# 15  False
# 16  False
# 17  False
# 18  False
# 19  False
# 20  False
# 21  False
# 22  False
# 23  False
# 24  False
# 25  False
# 26  False
# 27  False
# 28  False
# 29  False
# 30  False
# 31  False
# 32  False
# 33  False
# 34  False
# 35  False
# 36  False
# 37  False
# 38  False
# 39  False
#
#        f0  \
# 0   False
# 1   False
# 2   False
# 3   False
# 4   False
# 5   False
# 6   False
# 7   False
# 8   False
# 9   False
# 10  False
# 11  False
# 12  False
# 13  False
# 14  False
# 15  False
# 16  False
# 17  False
# 18  False
# 19  False
# 20  False
# 21  False
# 22  False
# 23  False
# 24  False
# 25  False
# 26  False
# 27  False
# 28  False
# 29  False
# 30  False
# 31  False
# 32  False
# 33  False
# 34  False
# 35  False
# 36  False
# 37  False
# 38  False
# 39  False
#
# ...

# %%
def normalize(df):
    df_z_scaled = df.copy()

    for column in df_z_scaled.columns:
        if str(column) != 'id' and str(column) != 'product':
            df_z_scaled[column] = (df_z_scaled[column] -
                                   df_z_scaled[column].mean()) / df_z_scaled[column].std()
    return df_z_scaled

# %%
df = normalize(df)

# %%
df.hist(column='f0', bins=51)
# Out:
# array([[<Axes: title={'center': 'f0'}>]], dtype=object)
# array([[<Axes: title={'center': 'f0'}>]], dtype=object)

# %%
df_f0_clean = np.sqrt(df['f0'])

df_f0_clean.hist(bins=40)

mean = df_f0_clean.mean()
std = np.std(df_f0_clean)

plt.axvline(mean, color='g', linestyle='dashed', linewidth=2)
plt.axvline(mean - 3 * std, color='r', linestyle='dashed', linewidth=2)
plt.axvline(mean + 3 * std, color='r', linestyle='dashed', linewidth=2)
# Out:
# /Users/serbin-denis/PycharmProjects/modeling/venv/lib/python3.9/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# /Users/serbin-denis/PycharmProjects/modeling/venv/lib/python3.9/site-packages/pandas/core/arraylike.py:402: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)

# %%
df.hist(column='f1', bins=40)

mean = df['f1'].mean()
std = np.std(df['f1'])

plt.axvline(mean, color='g', linestyle='dashed', linewidth=2)
plt.axvline(mean - 3 * std, color='r', linestyle='dashed', linewidth=2)
plt.axvline(mean + 3 * std, color='r', linestyle='dashed', linewidth=2)
print(mean + 3 * std)
# Out:
# 2.9622626487197246
# 2.9622626487197246

# %%
df.hist(column='f2', bins=40)

mean = df['f2'].mean()
std = np.std(df['f2'])

plt.axvline(mean, color='g', linestyle='dashed', linewidth=2)
plt.axvline(mean - 3 * std, color='r', linestyle='dashed', linewidth=2)
plt.axvline(mean + 3 * std, color='r', linestyle='dashed', linewidth=2)
print(mean + 3 * std)
# Out:
# 2.962262648719725
# 2.962262648719725

# %%
q1 = df["f0"].quantile(0.25)
q3 = df["f0"].quantile(0.75)
iqr = q3 - q1
df = df[~((df["f0"] < (q1 - 1.5 * iqr)) | (df["f0"] > (q3 + 1.5 * iqr)))]
df
# Out:
#        id  \
# 0   kBEdx
# 1   62mP7
# 2   vyE1P
# 3   KcrkZ
# 4   AHL4O
# 5   HHckp
# 6   h5Ujo
# 7   muH9x
# 8   YiRkx
# 9   jG6Gi
# 10  7uHUe
# 11  OXyvW
# 12  cB8re
# 13  igmai
# 14  3OdkE
# 15  3tVUO
# 16  siveY
# 17  gIqzq
# 18  zO5EU
# 19  dkcEb
# 20  X1FZJ
# 21  eVFPS
# 22  TovFu
# 23  KQxAV
# 24  II0xj
# 25  AOrbK
# 26  DbtST
# 27  mqtSN
# 28  dqN1d
# 29  JPiGi
# 30  YVVPX
# 31  4NJv3
# 32  2DKVI
# 33  M57PU
# 34  5O3Zt
# 35  BZWmy
# 36  aArVp
# 37  EHH3V
# 38  fNWXc
# 39  957X9
#
#           f0  \
# 0  -1.935588
# 1   1.382000
# 2   0.474343
# 3  -1.717976
# 4   1.204082
# 5  -0.612590
# 6  -1.498279
# 7   0.244454
# 8   1.278080
# 9  -0.114294
# 10  1.099234
# 11  1.614177
# 12  0.641294
# 13  0.523349
# 14 -1.480467
# 15 -0.274864
# 16  1.158565
# 17  0.773228
# 18 -1.755559
# 19 -0.731127
# 20 -0.884802
# 21  0.013335
# 22  0.828896
# 23  0.994420
# 24  0.057081
# 25  0.029598
# 26 -0.294885
# 27  0.775654
# 28  0.940209
# 29 -1.473756
# 30  1.093554
# 31 -1.112219
# ...

# %%
q1 = df["f1"].quantile(0.25)
q3 = df["f1"].quantile(0.75)
iqr = q3 - q1
df = df[~((df["f1"] < (q1 - 1.5 * iqr)) | (df["f1"] > (q3 + 1.5 * iqr)))]
df
# Out:
#        id  \
# 0   kBEdx
# 1   62mP7
# 2   vyE1P
# 3   KcrkZ
# 4   AHL4O
# 5   HHckp
# 6   h5Ujo
# 7   muH9x
# 8   YiRkx
# 9   jG6Gi
# 10  7uHUe
# 11  OXyvW
# 12  cB8re
# 13  igmai
# 14  3OdkE
# 15  3tVUO
# 16  siveY
# 17  gIqzq
# 18  zO5EU
# 19  dkcEb
# 20  X1FZJ
# 21  eVFPS
# 22  TovFu
# 23  KQxAV
# 24  II0xj
# 25  AOrbK
# 26  DbtST
# 27  mqtSN
# 28  dqN1d
# 29  JPiGi
# 30  YVVPX
# 31  4NJv3
# 32  2DKVI
# 33  M57PU
# 34  5O3Zt
# 35  BZWmy
# 36  aArVp
# 37  EHH3V
# 38  fNWXc
# 39  957X9
#
#           f0  \
# 0  -1.935588
# 1   1.382000
# 2   0.474343
# 3  -1.717976
# 4   1.204082
# 5  -0.612590
# 6  -1.498279
# 7   0.244454
# 8   1.278080
# 9  -0.114294
# 10  1.099234
# 11  1.614177
# 12  0.641294
# 13  0.523349
# 14 -1.480467
# 15 -0.274864
# 16  1.158565
# 17  0.773228
# 18 -1.755559
# 19 -0.731127
# 20 -0.884802
# 21  0.013335
# 22  0.828896
# 23  0.994420
# 24  0.057081
# 25  0.029598
# 26 -0.294885
# 27  0.775654
# 28  0.940209
# 29 -1.473756
# 30  1.093554
# 31 -1.112219
# ...

# %%
q1 = df["f2"].quantile(0.25)
q3 = df["f2"].quantile(0.75)
iqr = q3 - q1
df = df[~((df["f2"] < (q1 - 1.5 * iqr)) | (df["f1"] > (q3 + 1.5 * iqr)))]
df
# Out:
#        id  \
# 0   kBEdx
# 1   62mP7
# 2   vyE1P
# 3   KcrkZ
# 4   AHL4O
# 5   HHckp
# 6   h5Ujo
# 7   muH9x
# 8   YiRkx
# 9   jG6Gi
# 10  7uHUe
# 11  OXyvW
# 12  cB8re
# 13  igmai
# 14  3OdkE
# 15  3tVUO
# 16  siveY
# 17  gIqzq
# 18  zO5EU
# 19  dkcEb
# 20  X1FZJ
# 21  eVFPS
# 22  TovFu
# 23  KQxAV
# 24  II0xj
# 25  AOrbK
# 26  DbtST
# 27  mqtSN
# 28  dqN1d
# 29  JPiGi
# 30  YVVPX
# 31  4NJv3
# 32  2DKVI
# 33  M57PU
# 34  5O3Zt
# 35  BZWmy
# 36  aArVp
# 37  EHH3V
# 38  fNWXc
# 39  957X9
#
#           f0  \
# 0  -1.935588
# 1   1.382000
# 2   0.474343
# 3  -1.717976
# 4   1.204082
# 5  -0.612590
# 6  -1.498279
# 7   0.244454
# 8   1.278080
# 9  -0.114294
# 10  1.099234
# 11  1.614177
# 12  0.641294
# 13  0.523349
# 14 -1.480467
# 15 -0.274864
# 16  1.158565
# 17  0.773228
# 18 -1.755559
# 19 -0.731127
# 20 -0.884802
# 21  0.013335
# 22  0.828896
# 23  0.994420
# 24  0.057081
# 25  0.029598
# 26 -0.294885
# 27  0.775654
# 28  0.940209
# 29 -1.473756
# 30  1.093554
# 31 -1.112219
# ...

# %%
data_columns = ['f0', 'f1', 'f2']

df_target = df['product']
df_data = df[data_columns]

x_train, x_test, y_train, y_test = train_test_split(df_data, df_target, test_size=0.25, random_state=125)
x_train
# Out:
#           f0  \
# 4   1.204082
# 1   1.382000
# 30  1.093554
# 25  0.029598
# 16  1.158565
# 7   0.244454
# 24  0.057081
# 15 -0.274864
# 37 -0.723060
# 36  0.432850
# 9  -0.114294
# 31 -1.112219
# 28  0.940209
# 12  0.641294
# 18 -1.755559
# 20 -0.884802
# 33 -0.494605
# 35 -0.156690
# 26 -0.294885
# 21  0.013335
# 27  0.775654
# 2   0.474343
# 38 -0.889311
# 0  -1.935588
# 22  0.828896
# 13  0.523349
# 3  -1.717976
# 23  0.994420
# 34 -0.778665
# 29 -1.473756
#
#           f1  \
# 4  -0.811057
# 1   0.328168
# 30  0.130663
# 25 -0.899065
# 16  1.893397
# 7   1.175142
# 24  0.519242
# 15 -0.354731
# 37  0.725364
# 36 -0.104592
# 9  -1.512836
# 31 -0.008815
# 28  1.454701
# 12 -0.310231
# 18  0.022314
# 20  0.721628
# 33 -1.765996
# 35 -1.315096
# 26  0.033035
# 21  0.241803
# 27  0.477355
# 2  -0.274879
# 38 -0.201785
# 0  -0.842404
# 22  1.757399
# 13  0.992740
# 3  -1.629966
# 23  0.343482
# 34 -0.670188
# 29  0.195815
#
#           f2
# 4   1.223083
# 1  -1.104108
# 30 -1.101572
# ...

# %%
lin_regr = linear_model.LinearRegression()

lin_regr.fit(x_train, y_train)
predict = lin_regr.predict(x_test)
y_score = lin_regr.score(x_test, y_test)
mse = mean_squared_error(y_test, predict) ** 0.5

# %%
print("Средний запас предсказанного на валидационной выборке сырья:", predict.mean(), '(тыс. баррелей)')
print(f"score: {y_score}")
print("RMSE модели линейной регрессии на валидационной выборке", mse)
# Out:
# Средний запас предсказанного на валидационной выборке сырья: 87.41388203357619 (тыс. баррелей)
# score: 0.999467606331832
# RMSE модели линейной регрессии на валидационной выборке 0.9654894998018428

# %%
REGION_BUDGET = 10_000_000_000
SEARCHING_WELLS = 500
BEST_WELLS = 200
PROFIT_PER_BARRELL = 450
PROFIT_PER_BARRELL_BY_PRODUCT = 450_000
PROB_DAMAGES = 0.025

# %%
def get_best_wells(predict_product):
    return sorted(predict_product, reverse=True)[:BEST_WELLS]

# %%
get_best_wells(predict)
# Out:
# [135.5031689896446,
#  135.08724932294882,
#  134.2567017011645,
#  111.54811504539242,
#  84.01297809980365,
#  83.31419980673053,
#  83.03413147601958,
#  54.37262429477567,
#  53.996817561733735,
#  -0.9871659624515843]
# [135.5031689896446,
#  135.08724932294882,
#  134.2567017011645,
#  111.54811504539242,
#  84.01297809980365,
#  83.31419980673053,
#  83.03413147601958,
#  54.37262429477567,
#  53.996817561733735,
#  -0.9871659624515843]

# %%
def get_profit(predict_product):
    profit = 0
    for product in predict_product:
        profit += product * PROFIT_PER_BARRELL_BY_PRODUCT
    return profit

# %%
def avg(predict_product):
    return sum(predict_product) / len(predict_product)

# %%
def check_damages(predict_product):
    profit = get_profit(predict_product)

    prob = profit / REGION_BUDGET

    if profit < REGION_BUDGET:
        return "Затраты меньше прибыли"

    if prob - 1 > PROB_DAMAGES:
        return "Вероятность убытков меньше"
    else:
        return "Вероятность убытков больше"

# %%
def get_average_profit(predict_product):
    return avg(predict_product) * PROFIT_PER_BARRELL_BY_PRODUCT

# %%
check_damages(predict)
# Out:
# 'Затраты меньше прибыли'
# 'Затраты меньше прибыли'

# %%
get_profit(predict)
# Out:
# 393362469.1510928
# 393362469.1510928

# %%
get_average_profit(predict)
# Out:
# 39336246.915109284
# 39336246.915109284
